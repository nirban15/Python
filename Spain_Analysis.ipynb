# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import io
# %cd "C:\Users\anirb\OneDrive" #ans a
# Out:
# C:\Users\anirb\OneDrive

# %%
spainecodf=pd.read_csv("Spain.csv") #ans a

# %%
#head
spainecodf.head() #answer b
# Out:
#    Year  Population, total  Population growth (annual %)  \
# 0  1990           38867322                      0.101829
# 1  1991           38966376                      0.254527
# 2  1992           39157685                      0.489758
# 3  1993           39361262                      0.518544
# 4  1994           39549108                      0.476101
#
#   Surface area (sq. km)  \
# 0                505990
# 1                505990
# 2                505990
# 3                505990
# 4                505990
#
#   Poverty headcount ratio at national poverty lines (% of population)  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
#    GNI, Atlas method (current US$)  \
# 0                     4.744120e+11
# 1                     5.337230e+11
# ...

# %%
#tail
spainecodf.tail()  #answer b
# Out:
#     Year  Population, total  Population growth (annual %)  \
# 28  2018           46797754                      0.437983
# 29  2019           47134837                      0.717716
# 30  2020           47365655                      0.488502
# 31  2021           47415750                      0.105706
# 32  2022           47615034                      0.419410
#
#    Surface area (sq. km)  \
# 28            505957.289
# 29            505952.796
# 30            505969.891
# 31                    ..
# 32                    ..
#
#    Poverty headcount ratio at national poverty lines (% of population)  \
# 28                                               20.7
# 29                                                 21
# 30                                               21.7
# 31                                                 ..
# 32                                                 ..
#
#     GNI, Atlas method (current US$)  \
# 28                     1.372430e+12
# ...

# %%
#shape: shape determines the number of rows and columns which are 33 rows and 61 columns
spainecodf.shape  #answer b
# Out:
# (33, 61)

# %%
#columns
spainecodf.columns  #answer b
# Out:
# Index(['Year', 'Population, total', 'Population growth (annual %)',
#        'Surface area (sq. km)',
#        'Poverty headcount ratio at national poverty lines (% of population)',
#        'GNI, Atlas method (current US$)',
#        'GNI per capita, Atlas method (current US$)',
#        'GNI, PPP (current international $)',
#        'GNI per capita, PPP (current international $)',
#        'Income share held by lowest 20%',
#        'Life expectancy at birth, total (years)',
#        'Fertility rate, total (births per woman)',
#        'Adolescent fertility rate (births per 1,000 women ages 15-19)',
#        'Contraceptive prevalence, any method (% of married women ages 15-49)',
#        'Births attended by skilled health staff (% of total)',
#        'Mortality rate, under-5 (per 1,000 live births)',
#        'Prevalence of underweight, weight for age (% of children under 5)',
#        'Immunization, measles (% of children ages 12-23 months)',
# ...

# %%
#info
spainecodf.info()  #answer b
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 61 columns):
#  #   Column                                                                                            Non-Null Count  Dtype
# ---  ------                                                                                            --------------  -----
#  0   Year                                                                                              33 non-null     int64
#  1   Population, total                                                                                 33 non-null     int64
#  2   Population growth (annual %)                                                                      33 non-null     float64
#  3   Surface area (sq. km)                                                                             33 non-null     object
# ...

# %%
#describe
spainecodf.describe()
# Out:
#              Year  Population, total  Population growth (annual %)  \
# count    33.00000       3.300000e+01                     33.000000
# mean   2006.00000       4.359945e+07                      0.618221
# std       9.66954       3.262441e+06                      0.617701
# min    1990.00000       3.886732e+07                     -0.327669
# 25%    1998.00000       4.022351e+07                      0.254527
# 50%    2006.00000       4.439732e+07                      0.441366
# 75%    2014.00000       4.659324e+07                      0.717716
# max    2022.00000       4.761503e+07                      1.851081
#
#        GNI, Atlas method (current US$)  \
# count                     3.300000e+01
# mean                      1.034063e+12
# std                       3.851633e+11
# min                       4.744120e+11
# 25%                       6.250790e+11
# 50%                       1.236590e+12
# 75%                       1.372430e+12
# max                       1.509570e+12
#
# ...

# %%
spain_ind=spainecodf[['GDP growth (annual %)','Inflation, GDP deflator (annual %)',
                     'Inflation, consumer prices (annual %)', 'Population growth (annual %)']]

# %%
spain_ind.skew() #answer c
# Out:
# GDP growth (annual %)                   -2.335769
# Inflation, GDP deflator (annual %)       0.367120
# Inflation, consumer prices (annual %)    0.425069
# Population growth (annual %)             0.859812
# dtype: float64

# %%
spain_ind.kurt() #answer c
# Out:
# GDP growth (annual %)                    7.421508
# Inflation, GDP deflator (annual %)      -0.470712
# Inflation, consumer prices (annual %)    0.412706
# Population growth (annual %)            -0.224753
# dtype: float64

# %%
# Describe of Columns - GDP growth (annual %), Inflation, 
#GDP deflator (annual %), Inflation, consumer prices (annual %) and Population growth (annual %)
spain_ind.describe() #answer c
# Out:
#        GDP growth (annual %)  Inflation, GDP deflator (annual %)  \
# count              33.000000                           33.000000
# mean                1.916939                            2.767851
# std                 3.288091                            2.093560
# min               -11.325438                           -0.223723
# 25%                 0.929215                            1.225566
# 50%                 2.757494                            2.566602
# 75%                 3.781394                            4.084675
# max                 5.519595                            7.326251
#
#        Inflation, consumer prices (annual %)  Population growth (annual %)
# count                              33.000000                     33.000000
# mean                                2.888801                      0.618221
# std                                 2.091554                      0.617701
# min                                -0.500366                     -0.327669
# ...

# %%
spain_ind.skew()
# Out:
# GDP growth (annual %)                   -2.335769
# Inflation, GDP deflator (annual %)       0.367120
# Inflation, consumer prices (annual %)    0.425069
# Population growth (annual %)             0.859812
# dtype: float64

# %%
spain_ind.kurt()
# Out:
# GDP growth (annual %)                    7.421508
# Inflation, GDP deflator (annual %)      -0.470712
# Inflation, consumer prices (annual %)    0.412706
# Population growth (annual %)            -0.224753
# dtype: float64

# %%
# Line
spain_ind.plot(kind="line")
# Out:
# <Axes: >

# %%
import seaborn as sns

# %%
# GDP growth (annual %) #answer d
fig,ax=plt.subplots(3,1)
sns.histplot(spain_ind.iloc[:,0],ax=ax[0])
sns.boxplot(spain_ind.iloc[:,0],orient='h',ax=ax[1])
sns.kdeplot(spain_ind.iloc[:,0],ax=ax[2])
# There is an outlier which brings down the overall mean of the GDP growth
# There is a negatively skewed graph which indicates the bulk of data is concentrated on the right side
# There is an increase in the growth of the GDP except the outlier
# Out:
# <Axes: xlabel='GDP growth (annual %)', ylabel='Density'>

# %%
# Inflation, GDP deflator (annual %) #answer d
fig,ax=plt.subplots(3,1)
sns.histplot(spain_ind.iloc[:,1],ax=ax[0])
sns.boxplot(spain_ind.iloc[:,1],orient='h',ax=ax[1])
sns.kdeplot(spain_ind.iloc[:,1],ax=ax[2])
# There is no such outlier to bring down the overall mean of the Inflation, GDP deflator (annual %)
# There is no such negative or positive skewed graph that indicates the data is almost concentrated equally on both side
# Mostly the data is normally distributed for the Inflation, GDP deflator (annual %)
# Out:
# <Axes: xlabel='Inflation, GDP deflator (annual %)', ylabel='Density'>

# %%
# Inflation, consumer prices (annual %) #answer d
fig,ax=plt.subplots(3,1)
sns.histplot(spain_ind.iloc[:,2],ax=ax[0])
sns.boxplot(spain_ind.iloc[:,2],orient='h',ax=ax[1])
sns.kdeplot(spain_ind.iloc[:,2],ax=ax[2])
# Box plot is left skewed
# there are two outliers which has increased the median of the Inflation, consumer prices (annual %)
# values are concentrated in the range 2 and 4
# From the density curve I can infer that the data is mostly normally distributed
# Out:
# <Axes: xlabel='Inflation, consumer prices (annual %)', ylabel='Density'>

# %%
#Population growth (annual %) #answer d
fig,ax=plt.subplots(3,1)
sns.histplot(spain_ind.iloc[:,3],ax=ax[0])
sns.boxplot(spain_ind.iloc[:,3],orient='h',ax=ax[1])
sns.kdeplot(spain_ind.iloc[:,3],ax=ax[2])
# there are many outliers in the box plot
# the data is positively skewed that is right skewed. values are concentrated on the left side
# most of the data is the range of 0.2 to 1
# Out:
# <Axes: xlabel='Population growth (annual %)', ylabel='Density'>

# %%
# Calculate Average of Inflation, consumer prices (annual %) & - GDP growth (annual %)
print("Inflation, consumer prices (annual %): ",np.mean(spain_ind.iloc[:,2]))
print("GDP growth (annual %): ",np.mean(spain_ind.iloc[:,0]))
# Out:
# Inflation, consumer prices (annual %):  2.8888013385757576
# GDP growth (annual %):  1.9169388596060608

# %%
# Calculate variance of Inflation, consumer prices (annual %) & - GDP growth (annual %)
print("Inflation, consumer prices (annual %): ",np.var(spain_ind.iloc[:,2]))
print("GDP growth (annual %): ",np.var(spain_ind.iloc[:,0]))
# Out:
# Inflation, consumer prices (annual %):  4.24203461275316
# GDP growth (annual %):  10.483917015476953

# %%
# In the first case, the inflation rate is lower than the GDP growth rate. This means that the purchasing power of the currency is increasing. This is a good sign for the economy, 
# as it means that people are able to buy more goods and services with their money.
# In the second case, the inflation rate is higher than the GDP growth rate. This means that the purchasing power of the currency is decreasing. This is a bad sign for the economy, 
# as it means that people are able to buy fewer goods and services with their money.

# %%
# Test null average of Inflation, consumer prices (annual %) & - GDP growth (annual %) are equal
from scipy.stats import ttest_ind

# %%
ttest_ind(spain_ind.iloc[:,2],spain_ind.iloc[:,0],equal_var=False)
# Since pvalue=0.15769699594032488 is greater than 0.05, fail to reject null hypothesis
# Out:
# Ttest_indResult(statistic=1.4326434543562998, pvalue=0.15769699594032488)

# %%
print("GDP growth (annual %): ",np.mean(spain_ind.iloc[:,0]))
print("Inflation, GDP deflator (annual %): ",np.mean(spain_ind.iloc[:,1]))
print("Inflation, consumer prices (annual %): ",np.mean(spain_ind.iloc[:,2]))
print("Population growth (annual %): ",np.mean(spain_ind.iloc[:,3]))
# Out:
# GDP growth (annual %):  1.9169388596060608
# Inflation, GDP deflator (annual %):  2.767851412242424
# Inflation, consumer prices (annual %):  2.8888013385757576
# Population growth (annual %):  0.6182211938181819

# %%
# Test Null Average GDP growth (annual %), Inflation, GDP deflator (annual %), 
# Inflation, consumer prices (annual %) and Population growth (annual %) are equal.
from scipy.stats import f_oneway

# %%
f_oneway(spain_ind.iloc[:,0],spain_ind.iloc[:,1],spain_ind.iloc[:,2],spain_ind.iloc[:,3])
# since p-value is 0.00015719879736859237 which is less than 0.05, Reject Null hypothesis
# Out:
# F_onewayResult(statistic=7.248342306437579, pvalue=0.00015719879736859237)

# %%
# correlation
spain_ind.corr()
# Out:
#                                        GDP growth (annual %)  \
# GDP growth (annual %)                               1.000000
# Inflation, GDP deflator (annual %)                  0.378243
# Inflation, consumer prices (annual %)               0.371105
# Population growth (annual %)                        0.124985
#
#                                        Inflation, GDP deflator (annual %)  \
# GDP growth (annual %)                                            0.378243
# Inflation, GDP deflator (annual %)                               1.000000
# Inflation, consumer prices (annual %)                            0.808735
# Population growth (annual %)                                     0.298612
#
#                                        Inflation, consumer prices (annual %)  \
# GDP growth (annual %)                                               0.371105
# Inflation, GDP deflator (annual %)                                  0.808735
# ...

# %%
sns.heatmap(spain_ind.corr(),annot=True)
# Inflation, GDP deflator (annual %) & Inflation, consumer prices (annual %) are highly correlated with a value of 0.81
# Out:
# <Axes: >

# %%
# covariance
spain_ind.cov()
# Spain being a developed country has positive variance between GDP & Inflation i.e they are directly proportional
# Out:
#                                        GDP growth (annual %)  \
# GDP growth (annual %)                              10.811539
# Inflation, GDP deflator (annual %)                  2.603757
# Inflation, consumer prices (annual %)               2.552171
# Population growth (annual %)                        0.253851
#
#                                        Inflation, GDP deflator (annual %)  \
# GDP growth (annual %)                                            2.603757
# Inflation, GDP deflator (annual %)                               4.382995
# Inflation, consumer prices (annual %)                            3.541286
# Population growth (annual %)                                     0.386163
#
#                                        Inflation, consumer prices (annual %)  \
# GDP growth (annual %)                                               2.552171
# Inflation, GDP deflator (annual %)                                  3.541286
# ...

# %%
# scatter plot of all four variables
sns.pairplot(spain_ind)

# %%
# Scatter plot of GDP growth (annual %), Inflation, GDP deflator (annual %)
plt.figure(figsize=(8, 6))
plt.scatter(spain_ind['GDP growth (annual %)'],spain_ind['Inflation, GDP deflator (annual %)'], c='green', marker='o', alpha=0.7)
plt.xlabel('GDP Growth (annual %)')
plt.ylabel('Inflation, GDP Deflator (annual %)')
plt.title('Scatter Plot: GDP Growth vs. Inflation (GDP Deflator)')
plt.show()

# %%
# Consider variables Exports of goods and services (% of GDP) & Imports of goods and services (% of GDP). 
# Analyse the 2 variables over time. Trend Analysis
plt.figure(figsize=(10, 6))
plt.plot(spainecodf['Year'],spainecodf['Exports of goods and services (% of GDP)'], marker='o', label='Exports')
plt.plot(spainecodf['Year'],spainecodf['Imports of goods and services (% of GDP)'], marker='o', label='Imports')
plt.xlabel('Year')
plt.ylabel('Percentage of GDP')
plt.title('Trend Analysis: Exports vs. Imports')
plt.legend()
plt.grid(True)
plt.show()
# imports are higher than exports from 1990 to 2010. After 2010 exports are higher than imports
# After 2010, exports & imports on a rise and it is all time high now

# %%
# Analyze CO2 Emissions variable – Descriptive Statistics, Line Chart & Trend Analysis
spainecodf['CO2 emissions (metric tons per capita)'].describe()
# Out:
# count     33
# unique    32
# top       ..
# freq       2
# Name: CO2 emissions (metric tons per capita), dtype: object

# %%
spainecodf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 61 columns):
#  #   Column                                                                                            Non-Null Count  Dtype
# ---  ------                                                                                            --------------  -----
#  0   Year                                                                                              33 non-null     int64
#  1   Population, total                                                                                 33 non-null     int64
#  2   Population growth (annual %)                                                                      33 non-null     float64
#  3   Surface area (sq. km)                                                                             33 non-null     object
# ...

# %%
# converting the object datatype to numeric as the data itself is numeric
spainecodf['CO2 emissions (metric tons per capita)'] = pd.to_numeric(spainecodf['CO2 emissions (metric tons per capita)'], errors='coerce')

# %%
spainecodf['CO2 emissions (metric tons per capita)'].describe()
# Out:
# count    31.000000
# mean      6.240855
# std       0.974053
# min       4.279595
# 25%       5.539661
# 50%       5.893329
# 75%       7.136365
# max       8.029197
# Name: CO2 emissions (metric tons per capita), dtype: float64

# %%
# filling the missing value with mean
spainecodf['CO2 emissions (metric tons per capita)']=spainecodf['CO2 emissions (metric tons per capita)'].fillna(spainecodf['CO2 emissions (metric tons per capita)'].mean())

# %%
spainecodf['CO2 emissions (metric tons per capita)'].describe()
# Out:
# count    33.000000
# mean      6.240855
# std       0.943122
# min       4.279595
# 25%       5.540468
# 50%       5.934202
# 75%       7.056479
# max       8.029197
# Name: CO2 emissions (metric tons per capita), dtype: float64

# %%
plt.figure(figsize=(12, 6))
plt.plot(spainecodf['Year'], spainecodf['CO2 emissions (metric tons per capita)'], marker='o', linestyle='-', color='b')
plt.title('CO2 Emissions Over Time')
plt.xlabel('Year')
plt.ylabel('CO2 Emissions (Metric Tons)')
plt.grid(True)
plt.show()

# %%
# We can see that CO2 emission was rising from 1990 to 2005. It reaches the all time high to 8 in 2005.
# it started decreasing after 2005 and currently at a medium level

# %%
spainmacro_ind=spainecodf[['Population growth (annual %)','CO2 emissions (metric tons per capita)',
                 'GDP growth (annual %)','Industry (including construction), value added (% of GDP)',
                 'Exports of goods and services (% of GDP)','Imports of goods and services (% of GDP)',
                 'Gross capital formation (% of GDP)','Inflation, consumer prices (annual %)']]

# %%
spainmacro_ind.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 8 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   Population growth (annual %)                               33 non-null     float64
#  1   CO2 emissions (metric tons per capita)                     33 non-null     float64
#  2   GDP growth (annual %)                                      33 non-null     float64
#  3   Industry (including construction), value added (% of GDP)  33 non-null     object
#  4   Exports of goods and services (% of GDP)                   33 non-null     float64
#  5   Imports of goods and services (% of GDP)                   33 non-null     float64
#  6   Gross capital formation (% of GDP)                         33 non-null     float64
# ...

# %%
# object column converted to numeric to impute the missing value
spainmacro_ind['Industry (including construction), value added (% of GDP)'] = pd.to_numeric(spainmacro_ind['Industry (including construction), value added (% of GDP)'], errors='coerce')
# Out:
# C:\Users\anirb\AppData\Local\Temp\ipykernel_6560\1211209755.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spainmacro_ind['Industry (including construction), value added (% of GDP)'] = pd.to_numeric(spainmacro_ind['Industry (including construction), value added (% of GDP)'], errors='coerce')

# %%
spainmacro_ind.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 8 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   Population growth (annual %)                               33 non-null     float64
#  1   CO2 emissions (metric tons per capita)                     33 non-null     float64
#  2   GDP growth (annual %)                                      33 non-null     float64
#  3   Industry (including construction), value added (% of GDP)  28 non-null     float64
#  4   Exports of goods and services (% of GDP)                   33 non-null     float64
#  5   Imports of goods and services (% of GDP)                   33 non-null     float64
#  6   Gross capital formation (% of GDP)                         33 non-null     float64
# ...

# %%
spainmacro_ind['Industry (including construction), value added (% of GDP)'].describe()
# Out:
# count    28.000000
# mean     24.206279
# std       3.538422
# min      19.865948
# 25%      20.231768
# 50%      25.595050
# 75%      27.771198
# max      28.334433
# Name: Industry (including construction), value added (% of GDP), dtype: float64

# %%
# handling the missing by filling the blank column with mean
spainmacro_ind['Industry (including construction), value added (% of GDP)']=spainmacro_ind['Industry (including construction), value added (% of GDP)'].fillna(spainmacro_ind['Industry (including construction), value added (% of GDP)'].mean())
# Out:
# C:\Users\anirb\AppData\Local\Temp\ipykernel_6560\3297727915.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spainmacro_ind['Industry (including construction), value added (% of GDP)']=spainmacro_ind['Industry (including construction), value added (% of GDP)'].fillna(spainmacro_ind['Industry (including construction), value added (% of GDP)'].mean())

# %%
spainmacro_ind['Industry (including construction), value added (% of GDP)'].describe()
# Out:
# count    33.000000
# mean     24.206279
# std       3.250248
# min      19.865948
# 25%      20.357429
# 50%      24.206279
# 75%      27.421204
# max      28.334433
# Name: Industry (including construction), value added (% of GDP), dtype: float64

# %%
y=spainmacro_ind['GDP growth (annual %)']

# %%
x=spainmacro_ind[['Population growth (annual %)','CO2 emissions (metric tons per capita)',
                 'Industry (including construction), value added (% of GDP)',
                 'Exports of goods and services (% of GDP)','Imports of goods and services (% of GDP)',
                 'Gross capital formation (% of GDP)','Inflation, consumer prices (annual %)']]

# %%
x.corr()
# correlation value of the independent variable is not more than 0.95. 
# thus we can proceeds to built model as there is no multicollinearity
# Out:
#                                                     Population growth (annual %)  \
# Population growth (annual %)                                            1.000000
# CO2 emissions (metric tons per capita)                                  0.803000
# Industry (including construction), value added ...                      0.571892
# Exports of goods and services (% of GDP)                               -0.243887
# Imports of goods and services (% of GDP)                                0.115113
# Gross capital formation (% of GDP)                                      0.824283
# Inflation, consumer prices (annual %)                                   0.147336
#
#                                                     CO2 emissions (metric tons per capita)  \
# Population growth (annual %)                                                      0.803000
# CO2 emissions (metric tons per capita)                                            1.000000
# ...

# %%
spainmacro_ind.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 8 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   Population growth (annual %)                               33 non-null     float64
#  1   CO2 emissions (metric tons per capita)                     33 non-null     float64
#  2   GDP growth (annual %)                                      33 non-null     float64
#  3   Industry (including construction), value added (% of GDP)  33 non-null     float64
#  4   Exports of goods and services (% of GDP)                   33 non-null     float64
#  5   Imports of goods and services (% of GDP)                   33 non-null     float64
#  6   Gross capital formation (% of GDP)                         33 non-null     float64
# ...

# %%
# Multiple linear regression
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()

# %%
regmodel=reg.fit(x,y)

# %%
regmodel.score(x,y) 
# Since R square value is 0.5807106291099586. So, the independent variables
# can explain 69% of the changes in independent variable i.e. GDP growth.
# Out:
# 0.6930357285585168

# %%
regpredict=regmodel.predict(x)

# %%
regresidual=regmodel.predict(x)

# %%
regresidual=y-regpredict

# %%
np.sqrt(np.mean(regresidual**2)) 
# RMSE takes into consideration the square of error in forecasted 
# value over actual values. Thus, gives a much more accuracy.
# It is in our case is very low which teels that our model is accurately
# able to predict the values with existing variables 
# but must be considered in context of R square.
# Out:
# 1.7939308650304366

# %%
# Decision Tree
from sklearn.tree import DecisionTreeRegressor

# %%
tree=DecisionTreeRegressor()

# %%
treemodel=tree.fit(x,y)

# %%
treemodel.score(x,y)
# Out:
# 1.0

# %%
tree2=DecisionTreeRegressor(max_depth=5)

# %%
tree2model=tree2.fit(x,y)

# %%
tree2model.score(x,y)
# With depth of 5 score is coming below 0.95.I have reduced the max depth to 5 to control the overfitting
# Out:
# 0.9268304982682205

# %%
# Random Forest
from sklearn.ensemble import RandomForestRegressor

# %%
RF=RandomForestRegressor(n_estimators=1000)

# %%
RFmodel=RF.fit(x,y)

# %%
RFmodel.score(x,y)
# The score is low compared to decision tree. it does not lead to overfitting 
# It considers various parameters as well as random subset of training data to form decision tree.
# Out:
# 0.8851266004320635

# %%
# Gradient Boosting
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbm=GradientBoostingRegressor(n_estimators=3000)

# %%
gbmodel=gbm.fit(x,y)

# %%
gbmodel.score(x,y)
# Since, the result we get from Gradient Boosting Method is 1.0. 
# Thus, we can conveniently conclude that the method has accurately read the training data as it corrects the errors made by previous trees. But such
# high levels of accuracy can be a sign of overfitting.
# Out:
# 1.0

# %%
gbm1=GradientBoostingRegressor(n_estimators=1000)

# %%
gbmodel1=gbm1.fit(x,y)

# %%
gbmodel1.score(x,y)
# even after changing the estimator value the model still overfits
# Out:
# 1.0

# %%
# after doing all the model building I have found that the random forest is the best fiited model
